# %%
import ipywidgets as widgets
# pip install ipywidgets
from IPython.display import display

# %%
import ipywidgets as widgets
# pip install ipywidgets
from IPython.display import display
button = widgets.Button(description="Click Me")
def clickEvent(b):
    print("buttonClicked")
button.on_click(clickEvent)
display(button)
# Out:
# Button(description='Click Me', style=ButtonStyle())

# %%
slider = widgets.IntSlider(
    value=10,min=0,max=100,
    description = "Age"
)
display(slider)
# Out:
# IntSlider(value=10, description='Age')

# %%
text = widgets.Text(description="Name:",placeholder="Enter the Name:")
display(text)
# Out:
# Text(value='', description='Name:', placeholder='Enter the Name:')

# %%
check = widgets.Checkbox(value=False,description="Accept Terms")
display(check)
# Out:
# Checkbox(value=False, description='Accept Terms')

# %%
drop = widgets.Dropdown(
    options=["Java","Python","C","C++"]
)
display(drop)
# Out:
# Dropdown(options=('Java', 'Python', 'C', 'C++'), value='Java')

# %%
toggle = widgets.ToggleButton(
    value=False,
    description="Power"
)
display(toggle)
# Out:
# ToggleButton(value=False, description='Power')
